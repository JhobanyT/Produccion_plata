# %% [markdown]
# <a href="https://colab.research.google.com/github/JhobanyT/Produccion_plata/blob/main/Produccion_plata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PRODUCCIÓN DE PLATA ENTRE PERU Y MEXICO

# %% [markdown]
# Instalaciones

# %%
# !pip install bar-chart-race

# %% [markdown]
# Importaciones

# %%
import pandas as pd

# %% [markdown]
# PRODUCCION DE PLATA MENSUAL

# %%
# Url de los df_plata_mensual csv
url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQea6PHNNd_obgID8K9cADoYZbbBooJFuVjktYzD5TkyznZPgl8DqUEr3zarkvotA/pub?gid=1546344801&single=true&output=csv"

# Leer los df_plata_mensual de la url
df_plata_mensual = pd.read_csv(url,index_col="Fecha")

# Imprimir los df_plata_mensual de la url
print(df_plata_mensual)
# Out:
#                 Peru    Mexico
# Fecha
# 1/1/2010   299724.49  219285.0
# 2/1/2010   274512.23  251068.0
# 3/1/2010   296877.20  253705.0
# 4/1/2010   316334.88  292075.0
# 5/1/2010   303502.54  281683.0
# ...              ...       ...
# 8/1/2022   270285.83  355582.0
# 9/1/2022   254721.60  348976.0
# 10/1/2022  263906.42  341954.0
# 11/1/2022  244462.16  334327.0
# 12/1/2022  278608.26  329245.0
#
# [156 rows x 2 columns]

# %%
# IMPORTAMOS bar_chart_race
import bar_chart_race as bcarrera

# REALIZAMOS LOS GRAFICOS
bcarrera.bar_chart_race(df=df_plata_mensual,title="Produccion Mensual De Plata PERU Y MEXICO")
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="902" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# FUENTES

# %%
# DATA MEXICO:
# https://www.sgm.gob.mx/SINEMGobMx/produccion_minera.jsp

# DATA PERU
# https://estadisticas.bcrp.gob.pe/estadisticas/series/mensuales/resultados/RD12996DM/html/2020-1/2022-12/
